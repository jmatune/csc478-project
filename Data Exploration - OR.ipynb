# %%
import pandas as pd
import numpy as np
data=pd.read_csv('processed_nodummies.csv', index_col=0)
data.shape
# Out:
# (121, 54)

# %%
data.corr()
# Out:
#                                               Student_Count_Total  \
# Student_Count_Total                                      1.000000
# Student_Count_Low_Income                                 0.916546
# Student_Count_Special_Ed                                 0.691071
# Student_Count_English_Learners                           0.461219
# Student_Count_Black                                      0.223099
# Student_Count_Hispanic                                   0.784939
# Student_Count_White                                      0.742582
# Student_Count_Asian                                      0.692773
# Average_ACT_School                                       0.511578
# College_Enrollment_Rate_School                           0.382159
# Graduation_Rate_School                                   0.394248
# Growth_ACT_Grade_11_Pct                                  0.258348
# Attainment_ACT_Grade_11_Pct                              0.516508
# ...
