# %%
import pandas as pd
import numpy as np
data=pd.read_csv('processed_nodummies.csv', index_col=0)
data.shape
# Out:
# (121, 54)

# %%
data.corr()
# Out:
#                                               Student_Count_Total  \
# Student_Count_Total                                      1.000000
# Average_ACT_School                                       0.511578
# College_Enrollment_Rate_School                           0.382159
# Graduation_Rate_School                                   0.394248
# Growth_ACT_Grade_11_Pct                                  0.258348
# Attainment_ACT_Grade_11_Pct                              0.516508
# Freshmen_On_Track_School_Pct_Year_2                      0.197958
# Graduation_5_Year_School_Pct_Year_2                      0.394248
# College_Enrollment_School_Pct_Year_2                     0.382159
# College_Persistence_School_Pct_Year_2                    0.514897
# lib_cnt                                                 -0.171297
# PRED_NON_ENG_PERCENT                                     0.057571
# PERCENT OF HOUSING CROWDED                              -0.109958
# ...

# %% [markdown]
# Graduation rate appears to have a strong correlation with College_Enrollment_Rate_School. Student_Special_Ed_Pct has strong negative correlation with graduation rate.
#
# Couple variables look like duplicates: Graduation_5_Year_School_Pct_Year_2 (duplicate of Graduation_Rate_School),College_Enrollment_School_Pct_Year_2 (duplicate of College_Enrollment_Rate_School). Those variable will have to be dropped.
#
# Few variable have weak correlation with graduation rate: College_Persistence_School_Pct_Year_2 (0.47), Attainment_ACT_Grade_11_Pct (0.45), Growth_ACT_Grade_11_Pct (0.34), Average_ACT_School (0.46), Student_Count_Total (0.39).
